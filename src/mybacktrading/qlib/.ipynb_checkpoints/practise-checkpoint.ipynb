# %%
import qlib
import os
from qlib.contrib.model import LGBModel
from qlib.data.dataset import DatasetH
from qlib.workflow import R
# Out:
# ModuleNotFoundError. CatBoostModel are skipped. (optional: maybe installing CatBoostModel can fix it.)

# %%
qlib.init(provider_uri="~/.qlib/qlib_data/cn_data", region="cn")
os.environ["MLFLOW_ALLOW_FILE_STORE"] = "true"
# Out:
# [26068:MainThread](2026-08-14 23:15:06,280) INFO - qlib.Initialization - [config.py:473] - default_conf: client.
# [26068:MainThread](2026-08-14 23:15:06,285) INFO - qlib.Initialization - [__init__.py:82] - qlib successfully initialized based on client settings.
# [26068:MainThread](2026-08-14 23:15:06,286) INFO - qlib.Initialization - [__init__.py:84] - data_path={'__DEFAULT_FREQ': WindowsPath('C:/Users/Joe/.qlib/qlib_data/cn_data')}

# %%
handler_config = {
        "start_time": "2019-01-01",
        "end_time": "2026-08-10",
        "fit_start_time": "2010-01-01",
        "fit_end_time": "2026-08-10",
        "instruments": ["csi300"],
        "infer_processors": [],

    }

# %%
dataset = DatasetH(
        handler={
            "class": "Alpha158",
            "module_path": "qlib.contrib.data.handler",
            "kwargs": handler_config,
        },
        segments={
            "train": ("2010-01-01", "2020-12-31"),
            "valid": ("2021-01-01", "2021-12-31"),
            "test": ("2022-01-01", "2025-12-31"),
        }
    )
# Out:
# [26068:MainThread](2026-08-14 23:15:09,588) INFO - qlib.timer - [log.py:127] - Time cost: 0.255s | Loading data Done
# [26068:MainThread](2026-08-14 23:15:09,591) INFO - qlib.timer - [log.py:127] - Time cost: 0.001s | DropnaLabel Done
# [26068:MainThread](2026-08-14 23:15:09,595) INFO - qlib.timer - [log.py:127] - Time cost: 0.002s | CSZScoreNorm Done
# [26068:MainThread](2026-08-14 23:15:09,597) INFO - qlib.timer - [log.py:127] - Time cost: 0.007s | fit & process data Done
# [26068:MainThread](2026-08-14 23:15:09,599) INFO - qlib.timer - [log.py:127] - Time cost: 0.265s | Init data Done

# %%
model = LGBModel(
        eval_metric="rmse",
        colsample_bytree=0.8879,
        learning_rate=0.2,
        subsample=0.8789,
        lambda_l1=205.6999,
        lambda_l2=580.9768,
        max_depth=8,
        num_leaves=210,
        num_threads=20
    )

# %%
with R.start(experiment_name="test"):
    model.fit(dataset)

    R.save_objects(trained_model=model)

    recorder = R.get_recorder()
    print(f"实验ID: {recorder.id}")
# Out:
# [25556:MainThread](2026-08-14 23:05:44,138) WARNING - qlib.workflow - [expm.py:230] - No valid experiment found. Create a new experiment with name test.
# [25556:MainThread](2026-08-14 23:05:44,198) INFO - qlib.workflow - [exp.py:258] - Experiment 851594996292352946 starts running ...
# [25556:MainThread](2026-08-14 23:05:44,537) INFO - qlib.workflow - [recorder.py:345] - Recorder 6949976894d643ff9b813290ad8c5b2b starts running under Experiment 851594996292352946 ...
# Training until validation scores don't improve for 50 rounds
# [20]	train's l2: 0	valid's l2: 0
# [40]	train's l2: 0	valid's l2: 0
# Early stopping, best iteration is:
# [1]	train's l2: 0	valid's l2: 0
# 实验ID: 6949976894d643ff9b813290ad8c5b2b
# [25556:MainThread](2026-08-14 23:05:45,242) INFO - qlib.timer - [log.py:127] - Time cost: 0.293s | waiting `async_log` Done

# %%
predictions = model.predict(dataset=dataset)

# %%
predictions
# Out:
# datetime    instrument
# 2022-01-04  SH518880      0.0
# 2022-01-05  SH518880      0.0
# 2022-01-06  SH518880      0.0
# 2022-01-07  SH518880      0.0
# 2022-01-10  SH518880      0.0
#                          ...
# 2025-12-25  SH518880      0.0
# 2025-12-26  SH518880      0.0
# 2025-12-29  SH518880      0.0
# 2025-12-30  SH518880      0.0
# 2025-12-31  SH518880      0.0
# Length: 969, dtype: float64

# %%
dataset
# Out:
# DatasetH(handler=<qlib.contrib.data.handler.Alpha158 object at 0x000001A6557B28A0>, segments={'train': ('2010-01-01', '2020-12-31'), 'valid': ('2021-01-01', '2021-12-31'), 'test': ('2022-01-01', '2025-12-31')})
